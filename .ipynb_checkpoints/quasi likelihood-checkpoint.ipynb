# %%
import os
import tempfile
import anndata
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr
import scvi
import seaborn as sns
import torch

from _quasiSCVI import QuasiSCVI
from _quasivae import QuasiVAE

# %%
scvi.settings.seed = 0
print("Last run with scvi-tools version:", scvi.__version__)
# Out:
# Seed set to 0
# Last run with scvi-tools version: 1.1.3

# %% [markdown]
# ```{note}
# You can modify `save_dir` below to change where the data files for this tutorial are saved.
# ```

# %%
sc.set_figure_params(figsize=(6, 6), frameon=False)
sns.set_theme()
torch.set_float32_matmul_precision("high")
save_dir = tempfile.TemporaryDirectory()

# %config InlineBackend.print_figure_kwargs={"facecolor": "w"}
# %config InlineBackend.figure_format="retina"

# %% [markdown]
# Here we use the pancreas dataset described in the [scIB](https://github.com/theislab/scib) manuscript, that is also widely used to benchmark integration methods.

# %%
pancreas_adata_path = "/Users/ismail/thesis/Human Pancreas Normal.h5ad"

pancreas_adata = sc.read(
    pancreas_adata_path,
    backup_url="https://figshare.com/ndownloader/files/24539828",
)
pancreas_adata
# Out:
# AnnData object with n_obs × n_vars = 16382 × 19093
#     obs: 'tech', 'celltype', 'size_factors'
#     layers: 'counts'

# %% [markdown]
# We consider the SS2 and CelSeq2 samples as query, and all the others as reference.

# %%
query_mask = np.array([s in ["smartseq2", "celseq2"] for s in pancreas_adata.obs["tech"]])

pancreas_ref = pancreas_adata[~query_mask].copy()
pancreas_query = pancreas_adata[query_mask].copy()

# %% [markdown]
# We run highly variable gene selection on the reference data and use these same genes for the query data.

# %%
sc.pp.highly_variable_genes(pancreas_ref, n_top_genes=2000, batch_key="tech", subset=True)

pancreas_query = pancreas_query[:, pancreas_ref.var_names].copy()

# %%
#### Quasi Likelihood Model

# %%
QuasiSCVI.setup_anndata(pancreas_ref, batch_key="tech", layer="counts")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/data/fields/_base_field.py:64: UserWarning: adata.layers[counts] does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)

# %%
pancreas_adata.obs["tech"].unique()
# Out:
# ['celseq', 'celseq2', 'fluidigmc1', 'smartseq2', 'inDrop1', 'inDrop2', 'inDrop3', 'inDrop4', 'smarter']
# Categories (9, object): ['celseq', 'celseq2', 'fluidigmc1', 'inDrop1', ..., 'inDrop3', 'inDrop4', 'smarter', 'smartseq2']

# %% [markdown]
# We train the reference using the standard SCVI workflow, except we add a few non-default parameters that were identified to work well with scArches.

# %%
# Initialize the custom SCVI model
scvi_ref = QuasiSCVI(
    pancreas_ref,
    use_layer_norm="both",
    use_batch_norm="none",
    encode_covariates=True,
    dropout_rate=0.2,
    n_layers=2,
)

# Train the model
scvi_ref.train()
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/trainer/setup.py:187: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# Epoch 1/400:   0%|                                                                                                                            | 0/400 [00:00<?, ?it/s]128
# max value in px_rate: 337.355712890625
# max value in px_r: 22.139724731445312
# max value in residual: 944550784.0
# Max value in variance: 722184.5
# Max value in quasi_likelihood_log: 13.781235694885254
# Max value in reconst_loss: 969.060302734375
# 128
# max value in px_rate: 337.3983154296875
# max value in px_r: 22.161657333374023
# max value in residual: 288241952.0
# Max value in variance: 632201.375
# Max value in quasi_likelihood_log: 13.816965103149414
# Max value in reconst_loss: 977.154541015625
# 128
# max value in px_rate: 161.9641876220703
# max value in px_r: 22.183610916137695
# max value in residual: 369945248.0
# Max value in variance: 118308.9140625
# Max value in quasi_likelihood_log: 14.360833168029785
# Max value in reconst_loss: 893.8389892578125
# 128
# max value in px_rate: 210.92295837402344
# max value in px_r: 22.20558738708496
# max value in residual: 169405760.0
# Max value in variance: 240117.21875
# Max value in quasi_likelihood_log: 14.588630676269531
# Max value in reconst_loss: 877.9835205078125
# 128
# max value in px_rate: 202.8162841796875
# max value in px_r: 22.227584838867188
# max value in residual: 185414464.0
# Max value in variance: 122752.3359375
# Max value in quasi_likelihood_log: 13.284163475036621
# Max value in reconst_loss: 853.1715698242188
# 128
# max value in px_rate: 373.4360046386719
# max value in px_r: 22.249605178833008
# max value in residual: 753228032.0
# Max value in variance: 259623.3125
# Max value in quasi_likelihood_log: 13.671435356140137
# Max value in reconst_loss: 829.72021484375
# 128
# max value in px_rate: 313.87664794921875
# max value in px_r: 22.27164649963379
# max value in residual: 215860544.0
# Max value in variance: 217088.921875
# Max value in quasi_likelihood_log: 13.483277320861816
# Max value in reconst_loss: 838.8031616210938
# 128
# max value in px_rate: 676.1915893554688
# max value in px_r: 22.29370880126953
# max value in residual: 1289311232.0
# Max value in variance: 1303664.5
# Max value in quasi_likelihood_log: 14.15850830078125
# Max value in reconst_loss: 843.8140869140625
# 128
# max value in px_rate: 347.9049072265625
# max value in px_r: 22.315793991088867
# max value in residual: 1861698304.0
# Max value in variance: 404741.0
# Max value in quasi_likelihood_log: 13.672933578491211
# Max value in reconst_loss: 813.103271484375
# 128
# max value in px_rate: 352.7419128417969
# max value in px_r: 22.337902069091797
# max value in residual: 395823776.0
# Max value in variance: 352942.71875
# Max value in quasi_likelihood_log: 14.169597625732422
# Max value in reconst_loss: 771.6773681640625
# 128
# max value in px_rate: 342.9237060546875
# max value in px_r: 22.360031127929688
# max value in residual: 155490160.0
# Max value in variance: 380088.59375
# Max value in quasi_likelihood_log: 14.533045768737793
# Max value in reconst_loss: 776.7357177734375
# 128
# max value in px_rate: 461.06195068359375
# max value in px_r: 22.38218116760254
# max value in residual: 289802208.0
# Max value in variance: 646981.6875
# Max value in quasi_likelihood_log: 13.806861877441406
# Max value in reconst_loss: 780.8953857421875
# 128
# max value in px_rate: 323.1653137207031
# max value in px_r: 22.404354095458984
# max value in residual: 429699456.0
# Max value in variance: 524916.9375
# Max value in quasi_likelihood_log: 12.861319541931152
# Max value in reconst_loss: 786.1768798828125
# 128
# max value in px_rate: 285.5251770019531
# max value in px_r: 22.42654800415039
# max value in residual: 144301360.0
# Max value in variance: 242727.78125
# Max value in quasi_likelihood_log: 13.166950225830078
# Max value in reconst_loss: 765.7070922851562
# 128
# max value in px_rate: 427.8912658691406
# max value in px_r: 22.44876480102539
# max value in residual: 366629760.0
# Max value in variance: 535822.4375
# Max value in quasi_likelihood_log: 14.047347068786621
# Max value in reconst_loss: 825.7950439453125
# 128
# max value in px_rate: 399.01409912109375
# max value in px_r: 22.471004486083984
# max value in residual: 203062448.0
# Max value in variance: 283215.375
# Max value in quasi_likelihood_log: 14.743240356445312
# Max value in reconst_loss: 738.08984375
# 128
# max value in px_rate: 373.3651428222656
# max value in px_r: 22.49326515197754
# max value in residual: 264659616.0
# Max value in variance: 421676.78125
# Max value in quasi_likelihood_log: 13.687868118286133
# Max value in reconst_loss: 726.5929565429688
# 128
# max value in px_rate: 427.84051513671875
# max value in px_r: 22.515546798706055
# max value in residual: 133861080.0
# Max value in variance: 630818.875
# Max value in quasi_likelihood_log: 12.135024070739746
# Max value in reconst_loss: 736.38623046875
# 128
# max value in px_rate: 413.5226135253906
# max value in px_r: 22.537853240966797
# max value in residual: 168297136.0
# Max value in variance: 269980.625
# Max value in quasi_likelihood_log: 13.528315544128418
# Max value in reconst_loss: 727.1964111328125
# 128
# max value in px_rate: 431.2663879394531
# max value in px_r: 22.560178756713867
# max value in residual: 132093336.0
# Max value in variance: 476825.25
# Max value in quasi_likelihood_log: 13.65878677368164
# Max value in reconst_loss: 704.2945556640625
# 128
# max value in px_rate: 429.8871154785156
# max value in px_r: 22.582529067993164
# max value in residual: 226333840.0
# Max value in variance: 741111.375
# Max value in quasi_likelihood_log: 13.443781852722168
# Max value in reconst_loss: 679.5869140625
# 128
# max value in px_rate: 367.9610595703125
# max value in px_r: 22.604900360107422
# max value in residual: 432397824.0
# Max value in variance: 813605.875
# Max value in quasi_likelihood_log: 13.660572052001953
# Max value in reconst_loss: 717.8656005859375
# 128
# max value in px_rate: 401.81195068359375
# max value in px_r: 22.62729263305664
# max value in residual: 388613696.0
# Max value in variance: 418635.96875
# Max value in quasi_likelihood_log: 13.784356117248535
# Max value in reconst_loss: 670.5215454101562
# 128
# max value in px_rate: 217.50784301757812
# max value in px_r: 22.649707794189453
# max value in residual: 122462368.0
# Max value in variance: 138676.875
# Max value in quasi_likelihood_log: 13.352777481079102
# Max value in reconst_loss: 643.2599487304688
# 128
# max value in px_rate: 598.6360473632812
# max value in px_r: 22.67214584350586
# max value in residual: 356830848.0
# Max value in variance: 1068640.0
# Max value in quasi_likelihood_log: 12.557133674621582
# Max value in reconst_loss: 654.1407470703125
# 128
# max value in px_rate: 423.6282653808594
# max value in px_r: 22.69460678100586
# max value in residual: 642218624.0
# Max value in variance: 694860.25
# Max value in quasi_likelihood_log: 15.340214729309082
# Max value in reconst_loss: 632.296142578125
# 128
# max value in px_rate: 405.60009765625
# max value in px_r: 22.71708869934082
# max value in residual: 213259904.0
# Max value in variance: 993474.125
# Max value in quasi_likelihood_log: 12.834399223327637
# Max value in reconst_loss: 651.660888671875
# 128
# max value in px_rate: 666.0731811523438
# max value in px_r: 22.739593505859375
# max value in residual: 4289704448.0
# Max value in variance: 1525659.625
# Max value in quasi_likelihood_log: 13.176623344421387
# Max value in reconst_loss: 686.083251953125
# 128
# max value in px_rate: 620.209716796875
# max value in px_r: 22.76211929321289
# max value in residual: 973941440.0
# Max value in variance: 701326.4375
# Max value in quasi_likelihood_log: 13.768529891967773
# Max value in reconst_loss: 640.6661987304688
# 128
# max value in px_rate: 389.5543212890625
# max value in px_r: 22.784669876098633
# max value in residual: 275295360.0
# Max value in variance: 833840.0
# Max value in quasi_likelihood_log: 13.554619789123535
# Max value in reconst_loss: 622.7277221679688
# 128
# max value in px_rate: 372.18743896484375
# max value in px_r: 22.807241439819336
# max value in residual: 144763824.0
# Max value in variance: 542814.9375
# Max value in quasi_likelihood_log: 12.231602668762207
# Max value in reconst_loss: 643.32470703125
# 128
# max value in px_rate: 560.8967895507812
# max value in px_r: 22.829833984375
# max value in residual: 356502176.0
# Max value in variance: 685598.1875
# Max value in quasi_likelihood_log: 13.08172607421875
# Max value in reconst_loss: 608.4218139648438
# 128
# max value in px_rate: 414.366943359375
# max value in px_r: 22.85245132446289
# max value in residual: 166314400.0
# Max value in variance: 654772.8125
# Max value in quasi_likelihood_log: 12.89297866821289
# Max value in reconst_loss: 573.4738159179688
# 128
# max value in px_rate: 583.9396362304688
# max value in px_r: 22.875089645385742
# max value in residual: 2191021056.0
# Max value in variance: 872091.5625
# Max value in quasi_likelihood_log: 12.490053176879883
# Max value in reconst_loss: 604.6220703125
# 128
# max value in px_rate: 824.2796020507812
# max value in px_r: 22.897750854492188
# max value in residual: 237397072.0
# Max value in variance: 2780941.25
# Max value in quasi_likelihood_log: 14.08090591430664
# Max value in reconst_loss: 570.3768920898438
# 128
# max value in px_rate: 599.0386352539062
# max value in px_r: 22.920433044433594
# max value in residual: 204445280.0
# Max value in variance: 2555159.75
# Max value in quasi_likelihood_log: 12.656580924987793
# Max value in reconst_loss: 600.4449462890625
# 128
# max value in px_rate: 785.3362426757812
# max value in px_r: 22.943140029907227
# max value in residual: 586488128.0
# Max value in variance: 1827570.875
# Max value in quasi_likelihood_log: 11.343606948852539
# Max value in reconst_loss: 563.4356689453125
# 128
# max value in px_rate: 737.2265625
# max value in px_r: 22.96586799621582
# max value in residual: 762361280.0
# Max value in variance: 1970217.5
# Max value in quasi_likelihood_log: 13.766817092895508
# Max value in reconst_loss: 585.8267822265625
# 128
# max value in px_rate: 388.9555358886719
# max value in px_r: 22.988618850708008
# max value in residual: 234122784.0
# Max value in variance: 363894.40625
# Max value in quasi_likelihood_log: 13.320934295654297
# Max value in reconst_loss: 578.1536865234375
# 128
# max value in px_rate: 470.47479248046875
# max value in px_r: 23.01139259338379
# max value in residual: 285295840.0
# Max value in variance: 645972.25
# Max value in quasi_likelihood_log: 12.863750457763672
# Max value in reconst_loss: 564.046630859375
# 128
# max value in px_rate: 741.8097534179688
# max value in px_r: 23.034189224243164
# max value in residual: 1627334784.0
# Max value in variance: 1583763.375
# Max value in quasi_likelihood_log: 13.229559898376465
# Max value in reconst_loss: 544.7501220703125
# 128
# max value in px_rate: 548.259033203125
# max value in px_r: 23.0570068359375
# max value in residual: 148657008.0
# Max value in variance: 1017197.8125
# Max value in quasi_likelihood_log: 12.308378219604492
# Max value in reconst_loss: 582.2542724609375
# 128
# max value in px_rate: 511.5368347167969
# max value in px_r: 23.079849243164062
# max value in residual: 309842496.0
# Max value in variance: 631901.3125
# Max value in quasi_likelihood_log: 13.399118423461914
# Max value in reconst_loss: 566.9512939453125
# 128
# max value in px_rate: 464.8342590332031
# max value in px_r: 23.102712631225586
# max value in residual: 206218720.0
# Max value in variance: 739074.625
# Max value in quasi_likelihood_log: 13.305291175842285
# Max value in reconst_loss: 533.6461181640625
# 128
# max value in px_rate: 524.3072509765625
# max value in px_r: 23.125598907470703
# max value in residual: 119009288.0
# Max value in variance: 786597.0625
# Max value in quasi_likelihood_log: 12.358758926391602
# Max value in reconst_loss: 536.9859008789062
# 128
# max value in px_rate: 514.1026611328125
# max value in px_r: 23.148508071899414
# max value in residual: 237985584.0
# Max value in variance: 1093635.5
# Max value in quasi_likelihood_log: 13.301344871520996
# Max value in reconst_loss: 551.129638671875
# 128
# max value in px_rate: 584.1021118164062
# max value in px_r: 23.17144012451172
# max value in residual: 250878352.0
# Max value in variance: 1413124.625
# Max value in quasi_likelihood_log: 13.732681274414062
# Max value in reconst_loss: 576.2272338867188
# 128
# max value in px_rate: 617.348876953125
# max value in px_r: 23.194395065307617
# max value in residual: 578136960.0
# Max value in variance: 1233387.375
# Max value in quasi_likelihood_log: 13.984174728393555
# Max value in reconst_loss: 495.87420654296875
# 128
# max value in px_rate: 722.2109375
# max value in px_r: 23.21737289428711
# max value in residual: 263648832.0
# Max value in variance: 2109878.75
# Max value in quasi_likelihood_log: 13.62208366394043
# Max value in reconst_loss: 488.81494140625
# 128
# max value in px_rate: 631.2384033203125
# max value in px_r: 23.240371704101562
# max value in residual: 430939392.0
# Max value in variance: 1176435.75
# Max value in quasi_likelihood_log: 11.767653465270996
# Max value in reconst_loss: 560.7733154296875
# 128
# max value in px_rate: 1663.3212890625
# max value in px_r: 23.263395309448242
# max value in residual: 3125742848.0
# Max value in variance: 8126157.0
# Max value in quasi_likelihood_log: 12.946354866027832
# Max value in reconst_loss: 476.4991455078125
# 128
# max value in px_rate: 637.7405395507812
# max value in px_r: 23.286441802978516
# max value in residual: 1138603776.0
# Max value in variance: 990953.8125
# Max value in quasi_likelihood_log: 12.932286262512207
# Max value in reconst_loss: 514.748046875
# 128
# max value in px_rate: 735.275146484375
# max value in px_r: 23.30950927734375
# max value in residual: 515883840.0
# Max value in variance: 1302741.875
# Max value in quasi_likelihood_log: 12.540939331054688
# Max value in reconst_loss: 576.9114379882812
# 128
# max value in px_rate: 959.287109375
# max value in px_r: 23.33260154724121
# max value in residual: 350845600.0
# Max value in variance: 2246583.5
# Max value in quasi_likelihood_log: 12.750373840332031
# Max value in reconst_loss: 468.077880859375
# 128
# max value in px_rate: 748.8847045898438
# max value in px_r: 23.355714797973633
# max value in residual: 108811832.0
# Max value in variance: 1651062.625
# Max value in quasi_likelihood_log: 15.165384292602539
# Max value in reconst_loss: 483.0439453125
# 128
# max value in px_rate: 1119.659423828125
# max value in px_r: 23.37885284423828
# max value in residual: 299091904.0
# Max value in variance: 4173350.5
# Max value in quasi_likelihood_log: 13.125012397766113
# Max value in reconst_loss: 664.7168579101562
# 128
# max value in px_rate: 201.83143615722656
# max value in px_r: 23.40201187133789
# max value in residual: 125596280.0
# Max value in variance: 99745.4140625
# Max value in quasi_likelihood_log: 14.262947082519531
# Max value in reconst_loss: 505.186279296875
# 128
# max value in px_rate: 1196.5048828125
# max value in px_r: 23.425195693969727
# max value in residual: 247553504.0
# Max value in variance: 3508926.0
# Max value in quasi_likelihood_log: 12.464080810546875
# Max value in reconst_loss: 536.8762817382812
# 128
# max value in px_rate: 768.1417846679688
# max value in px_r: 23.448400497436523
# max value in residual: 753390016.0
# Max value in variance: 1411437.375
# Max value in quasi_likelihood_log: 11.58067512512207
# Max value in reconst_loss: 453.62835693359375
# 128
# max value in px_rate: 677.6869506835938
# max value in px_r: 23.471630096435547
# max value in residual: 244540416.0
# Max value in variance: 1127881.625
# Max value in quasi_likelihood_log: 13.596456527709961
# Max value in reconst_loss: 458.91552734375
# 128
# max value in px_rate: 805.0336303710938
# max value in px_r: 23.494882583618164
# max value in residual: 99003296.0
# Max value in variance: 1593174.375
# Max value in quasi_likelihood_log: 11.453134536743164
# Max value in reconst_loss: 434.4290771484375
# 128
# max value in px_rate: 940.1318359375
# max value in px_r: 23.518157958984375
# max value in residual: 940062080.0
# Max value in variance: 2764877.5
# Max value in quasi_likelihood_log: 12.992925643920898
# Max value in reconst_loss: 541.4840698242188
# 128
# max value in px_rate: 949.41845703125
# max value in px_r: 23.54145622253418
# max value in residual: 1352844544.0
# Max value in variance: 2220294.75
# Max value in quasi_likelihood_log: 13.540267944335938
# Max value in reconst_loss: 482.3741455078125
# 128
# max value in px_rate: 854.6588745117188
# max value in px_r: 23.564777374267578
# max value in residual: 315244448.0
# Max value in variance: 1800988.375
# Max value in quasi_likelihood_log: 12.860815048217773
# Max value in reconst_loss: 469.75921630859375
# 128
# max value in px_rate: 794.7384033203125
# max value in px_r: 23.58812141418457
# max value in residual: 158283408.0
# Max value in variance: 1820803.5
# Max value in quasi_likelihood_log: 11.955020904541016
# Max value in reconst_loss: 468.7004089355469
# 128
# max value in px_rate: 993.3294067382812
# max value in px_r: 23.611488342285156
# max value in residual: 153643968.0
# Max value in variance: 2437652.75
# Max value in quasi_likelihood_log: 12.56964111328125
# Max value in reconst_loss: 441.0909118652344
# 128
# max value in px_rate: 911.9949951171875
# max value in px_r: 23.634878158569336
# max value in residual: 118095936.0
# Max value in variance: 2056838.375
# Max value in quasi_likelihood_log: 12.357660293579102
# Max value in reconst_loss: 503.0250244140625
# 128
# max value in px_rate: 985.095947265625
# max value in px_r: 23.658292770385742
# max value in residual: 272236928.0
# Max value in variance: 2402161.75
# Max value in quasi_likelihood_log: 12.52180004119873
# Max value in reconst_loss: 456.83404541015625
# 128
# max value in px_rate: 790.0265502929688
# max value in px_r: 23.681730270385742
# max value in residual: 493105216.0
# Max value in variance: 1546530.875
# Max value in quasi_likelihood_log: 13.01781940460205
# Max value in reconst_loss: 431.43487548828125
# 128
# max value in px_rate: 951.7955322265625
# max value in px_r: 23.705188751220703
# max value in residual: 1424527616.0
# Max value in variance: 2246945.5
# Max value in quasi_likelihood_log: 12.798726081848145
# Max value in reconst_loss: 411.9373474121094
# 128
# max value in px_rate: 1328.4322509765625
# max value in px_r: 23.728673934936523
# max value in residual: 595683840.0
# Max value in variance: 4381411.0
# Max value in quasi_likelihood_log: 16.227231979370117
# Max value in reconst_loss: 397.8382263183594
# 128
# max value in px_rate: 857.7348022460938
# max value in px_r: 23.752180099487305
# max value in residual: 129191552.0
# Max value in variance: 2278017.5
# Max value in quasi_likelihood_log: 12.705191612243652
# Max value in reconst_loss: 452.33489990234375
# 128
# max value in px_rate: 1514.8297119140625
# max value in px_r: 23.77570915222168
# max value in residual: 303467840.0
# Max value in variance: 5708510.5
# Max value in quasi_likelihood_log: 12.84225845336914
# Max value in reconst_loss: 450.3497314453125
# 128
# max value in px_rate: 650.9990234375
# max value in px_r: 23.79926300048828
# max value in residual: 191592848.0
# Max value in variance: 1055324.0
# Max value in quasi_likelihood_log: 12.885323524475098
# Max value in reconst_loss: 406.914794921875
# 128
# max value in px_rate: 1324.9267578125
# max value in px_r: 23.822839736938477
# max value in residual: 599445952.0
# Max value in variance: 4375613.0
# Max value in quasi_likelihood_log: 13.430115699768066
# Max value in reconst_loss: 446.4632263183594
# 128
# max value in px_rate: 924.7252197265625
# max value in px_r: 23.846439361572266
# max value in residual: 265991024.0
# Max value in variance: 2410408.25
# Max value in quasi_likelihood_log: 14.864866256713867
# Max value in reconst_loss: 421.63226318359375
# 128
# max value in px_rate: 871.9505004882812
# max value in px_r: 23.87006187438965
# max value in residual: 98817752.0
# Max value in variance: 1898885.625
# Max value in quasi_likelihood_log: 13.031563758850098
# Max value in reconst_loss: 435.6471252441406
# 128
# max value in px_rate: 1050.4498291015625
# max value in px_r: 23.893709182739258
# max value in residual: 614900032.0
# Max value in variance: 2343326.25
# Max value in quasi_likelihood_log: 13.693355560302734
# Max value in reconst_loss: 382.2653503417969
# 128
# max value in px_rate: 669.3612060546875
# max value in px_r: 23.91737937927246
# max value in residual: 311331200.0
# Max value in variance: 741112.6875
# Max value in quasi_likelihood_log: 13.489091873168945
# Max value in reconst_loss: 361.0586242675781
# 128
# max value in px_rate: 604.7481689453125
# max value in px_r: 23.941072463989258
# max value in residual: 104167656.0
# Max value in variance: 794395.4375
# Max value in quasi_likelihood_log: 15.16427993774414
# Max value in reconst_loss: 388.1484680175781
# 128
# max value in px_rate: 1216.001953125
# max value in px_r: 23.96479034423828
# max value in residual: 214651136.0
# Max value in variance: 3029313.5
# Max value in quasi_likelihood_log: 13.12431526184082
# Max value in reconst_loss: 381.5950012207031
# 128
# max value in px_rate: 912.8292846679688
# max value in px_r: 23.9885311126709
# max value in residual: 209746368.0
# Max value in variance: 1753858.875
# Max value in quasi_likelihood_log: 12.3890380859375
# Max value in reconst_loss: 375.1197204589844
# 37
# max value in px_rate: 450.7560729980469
# max value in px_r: 24.01229476928711
# max value in residual: 101884024.0
# Max value in variance: 384496.65625
# Max value in quasi_likelihood_log: 11.727410316467285
# Max value in reconst_loss: 376.1513977050781
# Epoch 2/400:   0%|▏                                                               | 1/400 [00:00<04:50,  1.38it/s, v_num=1, train_loss_step=142, train_loss_epoch=298]128
# max value in px_rate: 1588.63671875
# max value in px_r: 24.036083221435547
# max value in residual: 125222768.0
# Max value in variance: 3578055.0
# Max value in quasi_likelihood_log: 12.245102882385254
# Max value in reconst_loss: 397.2835388183594
# 128
# max value in px_rate: 1075.02197265625
# max value in px_r: 24.059892654418945
# max value in residual: 177364048.0
# Max value in variance: 1895645.125
# Max value in quasi_likelihood_log: 12.910555839538574
# Max value in reconst_loss: 389.26611328125
# 128
# max value in px_rate: 1101.997802734375
# max value in px_r: 24.083728790283203
# max value in residual: 130782384.0
# Max value in variance: 1714035.5
# Max value in quasi_likelihood_log: 12.157853126525879
# Max value in reconst_loss: 378.7641906738281
# 128
# max value in px_rate: 850.278564453125
# max value in px_r: 24.107585906982422
# max value in residual: 129053864.0
# Max value in variance: 1549082.25
# Max value in quasi_likelihood_log: 12.92677116394043
# Max value in reconst_loss: 434.11932373046875
# 128
# max value in px_rate: 1508.4049072265625
# max value in px_r: 24.131467819213867
# max value in residual: 2142450944.0
# Max value in variance: 3110549.25
# Max value in quasi_likelihood_log: 11.859090805053711
# Max value in reconst_loss: 390.26190185546875
# 128
# max value in px_rate: 2069.0
# max value in px_r: 24.15537452697754
# max value in residual: 895667072.0
# Max value in variance: 5858038.5
# Max value in quasi_likelihood_log: 14.085049629211426
# Max value in reconst_loss: 419.3941650390625
# 128
# max value in px_rate: 1009.3546752929688
# max value in px_r: 24.179304122924805
# max value in residual: 576317696.0
# Max value in variance: 1395561.0
# Max value in quasi_likelihood_log: 13.936470985412598
# Max value in reconst_loss: 416.6029357910156
# 128
# max value in px_rate: 1292.65087890625
# max value in px_r: 24.203256607055664
# max value in residual: 124504208.0
# Max value in variance: 4207935.5
# Max value in quasi_likelihood_log: 12.340001106262207
# Max value in reconst_loss: 483.10040283203125
# 128
# max value in px_rate: 1491.4532470703125
# max value in px_r: 24.22723388671875
# max value in residual: 617447104.0
# Max value in variance: 3053096.25
# Max value in quasi_likelihood_log: 14.291109085083008
# Max value in reconst_loss: 318.0856628417969
# 128
# max value in px_rate: 881.304931640625
# max value in px_r: 24.25123405456543
# max value in residual: 343903904.0
# Max value in variance: 1094311.375
# Max value in quasi_likelihood_log: 13.954191207885742
# Max value in reconst_loss: 333.6725769042969
# 128
# max value in px_rate: 1133.144775390625
# max value in px_r: 24.275259017944336
# max value in residual: 99624728.0
# Max value in variance: 1765842.75
# Max value in quasi_likelihood_log: 13.26070499420166
# Max value in reconst_loss: 349.466064453125
# 128
# max value in px_rate: 1024.56494140625
# max value in px_r: 24.299306869506836
# max value in residual: 261707968.0
# Max value in variance: 2769280.25
# Max value in quasi_likelihood_log: 12.847380638122559
# Max value in reconst_loss: 371.59490966796875
# 128
# max value in px_rate: 1704.7288818359375
# max value in px_r: 24.32337760925293
# max value in residual: 1813058432.0
# Max value in variance: 4004532.5
# Max value in quasi_likelihood_log: 12.802892684936523
# Max value in reconst_loss: 452.95263671875
# 128
# max value in px_rate: 1177.5074462890625
# max value in px_r: 24.347475051879883
# max value in residual: 355938112.0
# Max value in variance: 4235159.5
# Max value in quasi_likelihood_log: 14.037247657775879
# Max value in reconst_loss: 352.5628356933594
# 128
# max value in px_rate: 1309.1148681640625
# max value in px_r: 24.371593475341797
# max value in residual: 345302048.0
# Max value in variance: 6934230.0
# Max value in quasi_likelihood_log: 13.06734561920166
# Max value in reconst_loss: 320.61651611328125
# 128
# max value in px_rate: 1044.9111328125
# max value in px_r: 24.395736694335938
# max value in residual: 234088144.0
# Max value in variance: 1509002.125
# Max value in quasi_likelihood_log: 12.450243949890137
# Max value in reconst_loss: 401.0936279296875
# 128
# max value in px_rate: 1882.901123046875
# max value in px_r: 24.419904708862305
# max value in residual: 122648400.0
# Max value in variance: 4904742.5
# Max value in quasi_likelihood_log: 13.88475227355957
# Max value in reconst_loss: 343.8056640625
# 128
# max value in px_rate: 2216.54736328125
# max value in px_r: 24.444095611572266
# max value in residual: 1429869312.0
# Max value in variance: 6803700.0
# Max value in quasi_likelihood_log: 12.85062026977539
# Max value in reconst_loss: 324.7407531738281
# 128
# max value in px_rate: 1267.7781982421875
# max value in px_r: 24.468311309814453
# max value in residual: 190286720.0
# Max value in variance: 2505012.0
# Max value in quasi_likelihood_log: 12.535873413085938
# Max value in reconst_loss: 361.0824890136719
# 128
# max value in px_rate: 1611.3839111328125
# max value in px_r: 24.492551803588867
# max value in residual: 1340368512.0
# Max value in variance: 3602874.75
# Max value in quasi_likelihood_log: 13.507699966430664
# Max value in reconst_loss: 379.0372619628906
# 128
# max value in px_rate: 1399.32080078125
# max value in px_r: 24.516815185546875
# max value in residual: 158101104.0
# Max value in variance: 4574254.0
# Max value in quasi_likelihood_log: 11.277973175048828
# Max value in reconst_loss: 354.95574951171875
# 128
# max value in px_rate: 1442.0543212890625
# max value in px_r: 24.541101455688477
# max value in residual: 1607594624.0
# Max value in variance: 3770611.0
# Max value in quasi_likelihood_log: 14.908374786376953
# Max value in reconst_loss: 336.6238708496094
# 128
# max value in px_rate: 1403.03515625
# max value in px_r: 24.565412521362305
# max value in residual: 1135961472.0
# Max value in variance: 3366279.75
# Max value in quasi_likelihood_log: 13.515793800354004
# Max value in reconst_loss: 386.6844482421875
# 128
# max value in px_rate: 643.1012573242188
# max value in px_r: 24.58974838256836
# max value in residual: 204535744.0
# Max value in variance: 695397.1875
# Max value in quasi_likelihood_log: 13.184205055236816
# Max value in reconst_loss: 415.2314453125
# 128
# max value in px_rate: 1317.705810546875
# max value in px_r: 24.61410903930664
# max value in residual: 179554640.0
# Max value in variance: 4332112.0
# Max value in quasi_likelihood_log: 13.839446067810059
# Max value in reconst_loss: 409.595458984375
# 128
# max value in px_rate: 1126.6683349609375
# max value in px_r: 24.638492584228516
# max value in residual: 155515536.0
# Max value in variance: 2277969.75
# Max value in quasi_likelihood_log: 14.097068786621094
# Max value in reconst_loss: 386.3337707519531
# 128
# max value in px_rate: 614.3466186523438
# max value in px_r: 24.662900924682617
# max value in residual: 154220992.0
# Max value in variance: 1135375.875
# Max value in quasi_likelihood_log: 13.1673002243042
# Max value in reconst_loss: 326.4969482421875
# 128
# max value in px_rate: 1474.1021728515625
# max value in px_r: 24.687332153320312
# max value in residual: 937695424.0
# Max value in variance: 3933036.5
# Max value in quasi_likelihood_log: 13.384618759155273
# Max value in reconst_loss: 446.27752685546875
# 128
# max value in px_rate: 817.6347045898438
# max value in px_r: 24.711788177490234
# max value in residual: 621873472.0
# Max value in variance: 2302485.25
# Max value in quasi_likelihood_log: 13.20246410369873
# Max value in reconst_loss: 310.9120788574219
# 128
# max value in px_rate: 819.1366577148438
# max value in px_r: 24.736268997192383
# max value in residual: 108733976.0
# Max value in variance: 2171907.25
# Max value in quasi_likelihood_log: 12.670677185058594
# Max value in reconst_loss: 337.01806640625
# 128
# max value in px_rate: 1307.3367919921875
# max value in px_r: 24.760774612426758
# max value in residual: 297158624.0
# Max value in variance: 5922455.5
# Max value in quasi_likelihood_log: 12.75940990447998
# Max value in reconst_loss: 303.89422607421875
# 128
# max value in px_rate: 1202.98828125
# max value in px_r: 24.785303115844727
# max value in residual: 317043680.0
# Max value in variance: 2032047.25
# Max value in quasi_likelihood_log: 13.495898246765137
# Max value in reconst_loss: 308.36419677734375
# 128
# max value in px_rate: 1199.1417236328125
# max value in px_r: 24.809856414794922
# max value in residual: 282848000.0
# Max value in variance: 4051930.75
# Max value in quasi_likelihood_log: 14.247929573059082
# Max value in reconst_loss: 290.09375
# 128
# max value in px_rate: 1002.5602416992188
# max value in px_r: 24.834434509277344
# max value in residual: 357178464.0
# Max value in variance: 2708750.5
# Max value in quasi_likelihood_log: 12.819073677062988
# Max value in reconst_loss: 343.7670593261719
# 128
# max value in px_rate: 2054.21826171875
# max value in px_r: 24.85903549194336
# max value in residual: 758260416.0
# Max value in variance: 5942841.5
# Max value in quasi_likelihood_log: 12.181281089782715
# Max value in reconst_loss: 334.00347900390625
# 128
# max value in px_rate: 831.2879028320312
# max value in px_r: 24.883663177490234
# max value in residual: 240398400.0
# Max value in variance: 2327601.5
# Max value in quasi_likelihood_log: 13.32297420501709
# Max value in reconst_loss: 326.3939514160156
# 128
# max value in px_rate: 1834.02587890625
# max value in px_r: 24.908313751220703
# max value in residual: 1238881280.0
# Max value in variance: 4746483.0
# Max value in quasi_likelihood_log: 12.711804389953613
# Max value in reconst_loss: 336.4490661621094
# 128
# max value in px_rate: 1131.001953125
# max value in px_r: 24.9329891204834
# max value in residual: 130539664.0
# Max value in variance: 1806831.625
# Max value in quasi_likelihood_log: 13.534330368041992
# Max value in reconst_loss: 272.7172546386719
# 128
# max value in px_rate: 1061.8583984375
# max value in px_r: 24.957687377929688
# max value in residual: 215310320.0
# Max value in variance: 3101749.0
# Max value in quasi_likelihood_log: 16.215084075927734
# Max value in reconst_loss: 375.0455322265625
# 128
# max value in px_rate: 912.8385620117188
# max value in px_r: 24.982412338256836
# max value in residual: 204501248.0
# Max value in variance: 1869588.0
# Max value in quasi_likelihood_log: 13.689765930175781
# Max value in reconst_loss: 290.94842529296875
# 128
# max value in px_rate: 961.65625
# max value in px_r: 25.007160186767578
# max value in residual: 952567680.0
# Max value in variance: 3058690.75
# Max value in quasi_likelihood_log: 13.151215553283691
# Max value in reconst_loss: 320.4135437011719
# 128
# max value in px_rate: 932.4923095703125
# max value in px_r: 25.03193473815918
# max value in residual: 210844528.0
# Max value in variance: 2414283.0
# Max value in quasi_likelihood_log: 13.354909896850586
# Max value in reconst_loss: 300.1222839355469
# 128
# max value in px_rate: 1244.4859619140625
# max value in px_r: 25.056732177734375
# max value in residual: 271270944.0
# Max value in variance: 2198472.0
# Max value in quasi_likelihood_log: 12.450130462646484
# Max value in reconst_loss: 278.54193115234375
# 128
# max value in px_rate: 1138.7232666015625
# max value in px_r: 25.081554412841797
# max value in residual: 95690256.0
# Max value in variance: 3489670.25
# Max value in quasi_likelihood_log: 13.475180625915527
# Max value in reconst_loss: 296.7309875488281
# 128
# max value in px_rate: 1706.447265625
# max value in px_r: 25.106401443481445
# max value in residual: 315889664.0
# Max value in variance: 4670136.0
# Max value in quasi_likelihood_log: 13.418270111083984
# Max value in reconst_loss: 299.817138671875
# 128
# max value in px_rate: 908.0505981445312
# max value in px_r: 25.13127326965332
# max value in residual: 310760576.0
# Max value in variance: 4224075.0
# Max value in quasi_likelihood_log: 13.971233367919922
# Max value in reconst_loss: 263.5964050292969
# 128
# max value in px_rate: 640.796630859375
# max value in px_r: 25.15616798400879
# max value in residual: 153589232.0
# Max value in variance: 681662.5625
# Max value in quasi_likelihood_log: 12.826669692993164
# Max value in reconst_loss: 268.6391906738281
# 128
# max value in px_rate: 511.3067321777344
# max value in px_r: 25.181089401245117
# max value in residual: 747509440.0
# Max value in variance: 968329.3125
# Max value in quasi_likelihood_log: 11.828575134277344
# Max value in reconst_loss: 276.89825439453125
# 128
# max value in px_rate: 1232.546630859375
# max value in px_r: 25.206035614013672
# max value in residual: 160566144.0
# Max value in variance: 2374632.5
# Max value in quasi_likelihood_log: 12.924627304077148
# Max value in reconst_loss: 260.9071044921875
# 128
# max value in px_rate: 563.0831909179688
# max value in px_r: 25.23100471496582
# max value in residual: 251593504.0
# Max value in variance: 1015740.75
# Max value in quasi_likelihood_log: 12.404614448547363
# Max value in reconst_loss: 296.3574523925781
# 128
# max value in px_rate: 798.0958862304688
# max value in px_r: 25.256000518798828
# max value in residual: 267543392.0
# Max value in variance: 2527153.25
# Max value in quasi_likelihood_log: 13.778116226196289
# Max value in reconst_loss: 274.14349365234375
# 128
# max value in px_rate: 865.8492431640625
# max value in px_r: 25.28101921081543
# max value in residual: 258257264.0
# Max value in variance: 3462272.75
# Max value in quasi_likelihood_log: 12.650726318359375
# Max value in reconst_loss: 254.95993041992188
# 128
# max value in px_rate: 1272.0721435546875
# max value in px_r: 25.30606460571289
# max value in residual: 283321952.0
# Max value in variance: 3670498.0
# Max value in quasi_likelihood_log: 12.878567695617676
# Max value in reconst_loss: 269.27655029296875
# 128
# max value in px_rate: 837.80078125
# max value in px_r: 25.331132888793945
# max value in residual: 283048672.0
# Max value in variance: 2989600.75
# Max value in quasi_likelihood_log: 13.173809051513672
# Max value in reconst_loss: 246.0198974609375
# 128
# max value in px_rate: 880.2310180664062
# max value in px_r: 25.35622787475586
# max value in residual: 151570528.0
# Max value in variance: 2828911.25
# Max value in quasi_likelihood_log: 12.244751930236816
# Max value in reconst_loss: 330.11688232421875
# 128
# max value in px_rate: 633.6810913085938
# max value in px_r: 25.381345748901367
# max value in residual: 104665032.0
# Max value in variance: 2137492.5
# Max value in quasi_likelihood_log: 13.312594413757324
# Max value in reconst_loss: 258.4290771484375
# 128
# max value in px_rate: 852.9520263671875
# max value in px_r: 25.406490325927734
# max value in residual: 203086880.0
# Max value in variance: 3099344.5
# Max value in quasi_likelihood_log: 11.913299560546875
# Max value in reconst_loss: 245.2103271484375
# 128
# max value in px_rate: 473.9356384277344
# max value in px_r: 25.431659698486328
# max value in residual: 127237808.0
# Max value in variance: 382072.90625
# Max value in quasi_likelihood_log: 16.105009078979492
# Max value in reconst_loss: 265.3763122558594
# 128
# max value in px_rate: 1158.122314453125
# max value in px_r: 25.456851959228516
# max value in residual: 242334352.0
# Max value in variance: 6237286.5
# Max value in quasi_likelihood_log: 12.41818618774414
# Max value in reconst_loss: 311.2705993652344
# 128
# max value in px_rate: 1259.5687255859375
# max value in px_r: 25.482070922851562
# max value in residual: 521127136.0
# Max value in variance: 7131292.5
# Max value in quasi_likelihood_log: 12.573662757873535
# Max value in reconst_loss: 252.0655975341797
# 128
# max value in px_rate: 1022.6765747070312
# max value in px_r: 25.507314682006836
# max value in residual: 309270496.0
# Max value in variance: 4873304.0
# Max value in quasi_likelihood_log: 16.527732849121094
# Max value in reconst_loss: 238.04339599609375
# 128
# max value in px_rate: 927.6531372070312
# max value in px_r: 25.532583236694336
# max value in residual: 242672448.0
# Max value in variance: 4211497.5
# Max value in quasi_likelihood_log: 13.616883277893066
# Max value in reconst_loss: 307.916259765625
# 128
# max value in px_rate: 2062.4755859375
# max value in px_r: 25.557876586914062
# max value in residual: 3183365888.0
# Max value in variance: 19860242.0
# Max value in quasi_likelihood_log: 12.799901008605957
# Max value in reconst_loss: 237.92691040039062
# 128
# max value in px_rate: 555.8663330078125
# max value in px_r: 25.58319664001465
# max value in residual: 110499560.0
# Max value in variance: 2146698.5
# Max value in quasi_likelihood_log: 14.551709175109863
# Max value in reconst_loss: 556.5220947265625
# 128
# max value in px_rate: 1190.60546875
# max value in px_r: 25.608539581298828
# max value in residual: 600711104.0
# Max value in variance: 6631361.5
# Max value in quasi_likelihood_log: 14.107525825500488
# Max value in reconst_loss: 230.00979614257812
# 128
# max value in px_rate: 933.9263916015625
# max value in px_r: 25.633909225463867
# max value in residual: 329495744.0
# Max value in variance: 5183821.5
# Max value in quasi_likelihood_log: 13.870826721191406
# Max value in reconst_loss: 277.22760009765625
# 128
# max value in px_rate: 1122.66748046875
# max value in px_r: 25.659303665161133
# max value in residual: 170218480.0
# Max value in variance: 5907847.0
# Max value in quasi_likelihood_log: 13.181070327758789
# Max value in reconst_loss: 234.64410400390625
# 128
# max value in px_rate: 738.7926025390625
# max value in px_r: 25.684722900390625
# max value in residual: 162677920.0
# Max value in variance: 2560955.5
# Max value in quasi_likelihood_log: 13.324365615844727
# Max value in reconst_loss: 223.53750610351562
# 128
# max value in px_rate: 1495.5216064453125
# max value in px_r: 25.710166931152344
# max value in residual: 748558784.0
# Max value in variance: 8613052.0
# Max value in quasi_likelihood_log: 12.971151351928711
# Max value in reconst_loss: 282.39813232421875
# 128
# max value in px_rate: 981.051513671875
# max value in px_r: 25.73563575744629
# max value in residual: 243198144.0
# Max value in variance: 4509640.0
# Max value in quasi_likelihood_log: 13.093453407287598
# Max value in reconst_loss: 229.43463134765625
# 128
# max value in px_rate: 1298.875244140625
# max value in px_r: 25.761131286621094
# max value in residual: 4242345728.0
# Max value in variance: 7939294.0
# Max value in quasi_likelihood_log: 13.975227355957031
# Max value in reconst_loss: 253.65536499023438
# 128
# max value in px_rate: 871.306640625
# max value in px_r: 25.786651611328125
# max value in residual: 430583488.0
# Max value in variance: 3576177.75
# Max value in quasi_likelihood_log: 12.613852500915527
# Max value in reconst_loss: 234.1331329345703
# 128
# max value in px_rate: 1337.794189453125
# max value in px_r: 25.812196731567383
# max value in residual: 379685152.0
# Max value in variance: 6944677.5
# Max value in quasi_likelihood_log: 12.709614753723145
# Max value in reconst_loss: 196.12698364257812
# 128
# max value in px_rate: 1456.378173828125
# max value in px_r: 25.837766647338867
# max value in residual: 565787712.0
# Max value in variance: 7626520.5
# Max value in quasi_likelihood_log: 13.244695663452148
# Max value in reconst_loss: 310.4040832519531
# 128
# max value in px_rate: 714.126953125
# max value in px_r: 25.86336326599121
# max value in residual: 125405744.0
# Max value in variance: 1412728.5
# Max value in quasi_likelihood_log: 12.734213829040527
# Max value in reconst_loss: 278.5919189453125
# 128
# max value in px_rate: 1343.6641845703125
# max value in px_r: 25.88898468017578
# max value in residual: 139455264.0
# Max value in variance: 5006328.5
# Max value in quasi_likelihood_log: 17.534177780151367
# Max value in reconst_loss: 264.3288879394531
# 128
# max value in px_rate: 1207.2376708984375
# max value in px_r: 25.914630889892578
# max value in residual: 286508384.0
# Max value in variance: 5964839.0
# Max value in quasi_likelihood_log: 15.341450691223145
# Max value in reconst_loss: 250.64315795898438
# 128
# max value in px_rate: 1885.2369384765625
# max value in px_r: 25.940303802490234
# max value in residual: 153941504.0
# Max value in variance: 16841820.0
# Max value in quasi_likelihood_log: 12.573532104492188
# Max value in reconst_loss: 226.29757690429688
# 128
# max value in px_rate: 1110.524658203125
# max value in px_r: 25.966001510620117
# max value in residual: 231164320.0
# Max value in variance: 3429922.75
# Max value in quasi_likelihood_log: 12.504938125610352
# Max value in reconst_loss: 177.1148223876953
# 128
# max value in px_rate: 1252.1695556640625
# max value in px_r: 25.991724014282227
# max value in residual: 419496416.0
# Max value in variance: 4491007.0
# Max value in quasi_likelihood_log: 14.635202407836914
# Max value in reconst_loss: 236.99920654296875
# 128
# max value in px_rate: 2080.359130859375
# max value in px_r: 26.017471313476562
# max value in residual: 430805376.0
# Max value in variance: 12060479.0
# Max value in quasi_likelihood_log: 13.31636905670166
# Max value in reconst_loss: 181.63255310058594
# 128
# max value in px_rate: 1003.1202392578125
# max value in px_r: 26.043245315551758
# max value in residual: 607571072.0
# Max value in variance: 2806880.75
# Max value in quasi_likelihood_log: 12.248420715332031
# Max value in reconst_loss: 217.84776306152344
# 37
# max value in px_rate: 1179.20166015625
# max value in px_r: 26.069046020507812
# max value in residual: 154249264.0
# Max value in variance: 3882613.25
# Max value in quasi_likelihood_log: 12.198736190795898
# Max value in reconst_loss: 150.9021759033203
# Epoch 3/400:   0%|▎                                                            | 2/400 [00:01<04:53,  1.36it/s, v_num=1, train_loss_step=-97.5, train_loss_epoch=1.59]128
# max value in px_rate: 1728.269775390625
# max value in px_r: 26.094871520996094
# max value in residual: 355110912.0
# Max value in variance: 8348358.5
# Max value in quasi_likelihood_log: 14.106820106506348
# Max value in reconst_loss: 213.68768310546875
# 128
# max value in px_rate: 1991.228759765625
# max value in px_r: 26.1207218170166
# max value in residual: 575286848.0
# Max value in variance: 11093034.0
# Max value in quasi_likelihood_log: 13.024067878723145
# Max value in reconst_loss: 229.12942504882812
# 128
# max value in px_rate: 3224.852294921875
# max value in px_r: 26.146596908569336
# max value in residual: 430064224.0
# Max value in variance: 29124446.0
# Max value in quasi_likelihood_log: 12.472602844238281
# Max value in reconst_loss: 170.12794494628906
# 128
# max value in px_rate: 2624.138916015625
# max value in px_r: 26.172500610351562
# max value in residual: 116269928.0
# Max value in variance: 19303750.0
# Max value in quasi_likelihood_log: 13.486974716186523
# Max value in reconst_loss: 202.04751586914062
# 128
# max value in px_rate: 5307.88623046875
# max value in px_r: 26.198427200317383
# max value in residual: 358154368.0
# Max value in variance: 79057176.0
# Max value in quasi_likelihood_log: 13.339051246643066
# Max value in reconst_loss: 159.46343994140625
# 128
# max value in px_rate: 3158.29931640625
# max value in px_r: 26.224380493164062
# max value in residual: 1831011456.0
# Max value in variance: 28017842.0
# Max value in quasi_likelihood_log: 13.154001235961914
# Max value in reconst_loss: 226.69989013671875
# 128
# max value in px_rate: 3047.407470703125
# max value in px_r: 26.2503604888916
# max value in residual: 196654560.0
# Max value in variance: 26110738.0
# Max value in quasi_likelihood_log: 13.263846397399902
# Max value in reconst_loss: 232.006103515625
# 128
# max value in px_rate: 2261.731689453125
# max value in px_r: 26.276365280151367
# max value in residual: 145403248.0
# Max value in variance: 14396943.0
# Max value in quasi_likelihood_log: 13.201080322265625
# Max value in reconst_loss: 186.79278564453125
# 128
# max value in px_rate: 2820.50634765625
# max value in px_r: 26.30239486694336
# max value in residual: 366586592.0
# Max value in variance: 22411572.0
# Max value in quasi_likelihood_log: 16.640300750732422
# Max value in reconst_loss: 178.46429443359375
# 128
# max value in px_rate: 2110.795654296875
# max value in px_r: 26.32845115661621
# max value in residual: 903606784.0
# Max value in variance: 12564365.0
# Max value in quasi_likelihood_log: 13.108635902404785
# Max value in reconst_loss: 186.0434112548828
# 128
# max value in px_rate: 1838.9437255859375
# max value in px_r: 26.354534149169922
# max value in residual: 771427712.0
# Max value in variance: 9545860.0
# Max value in quasi_likelihood_log: 13.44467544555664
# Max value in reconst_loss: 201.0053253173828
# 128
# max value in px_rate: 1826.1763916015625
# max value in px_r: 26.38064193725586
# max value in residual: 231901648.0
# Max value in variance: 9423097.0
# Max value in quasi_likelihood_log: 15.730806350708008
# Max value in reconst_loss: 558.9629516601562
# 128
# max value in px_rate: 2507.87890625
# max value in px_r: 26.406774520874023
# max value in residual: 215117104.0
# Max value in variance: 17788992.0
# Max value in quasi_likelihood_log: 13.498137474060059
# Max value in reconst_loss: 122.56536865234375
# 128
# max value in px_rate: 1962.7501220703125
# max value in px_r: 26.432933807373047
# max value in residual: 141249760.0
# Max value in variance: 10906823.0
# Max value in quasi_likelihood_log: 14.73194694519043
# Max value in reconst_loss: 158.2249755859375
# 128
# max value in px_rate: 2923.283935546875
# max value in px_r: 26.45911979675293
# max value in residual: 1607904128.0
# Max value in variance: 24218110.0
# Max value in quasi_likelihood_log: 14.48034381866455
# Max value in reconst_loss: 154.89280700683594
# 128
# max value in px_rate: 2046.9906005859375
# max value in px_r: 26.485332489013672
# max value in residual: 950802752.0
# Max value in variance: 11886663.0
# Max value in quasi_likelihood_log: 12.535527229309082
# Max value in reconst_loss: 249.93402099609375
# 128
# max value in px_rate: 2114.55615234375
# max value in px_r: 26.51156997680664
# max value in residual: 1235996800.0
# Max value in variance: 12696871.0
# Max value in quasi_likelihood_log: 14.475018501281738
# Max value in reconst_loss: 157.02996826171875
# 128
# max value in px_rate: 1743.068115234375
# max value in px_r: 26.537832260131836
# max value in residual: 149614992.0
# Max value in variance: 8636087.0
# Max value in quasi_likelihood_log: 11.89261531829834
# Max value in reconst_loss: 251.51800537109375
# 128
# max value in px_rate: 1932.5087890625
# max value in px_r: 26.564123153686523
# max value in residual: 120112824.0
# Max value in variance: 10625791.0
# Max value in quasi_likelihood_log: 13.435893058776855
# Max value in reconst_loss: 117.33137512207031
# 128
# max value in px_rate: 2890.5625
# max value in px_r: 26.590436935424805
# max value in residual: 4248019456.0
# Max value in variance: 24627774.0
# Max value in quasi_likelihood_log: 13.666095733642578
# Max value in reconst_loss: 348.24627685546875
# 128
# max value in px_rate: 2837.03564453125
# max value in px_r: 26.616779327392578
# max value in residual: 355849600.0
# Max value in variance: 22946048.0
# Max value in quasi_likelihood_log: 15.670297622680664
# Max value in reconst_loss: 191.5137939453125
# 128
# max value in px_rate: 3515.09228515625
# max value in px_r: 26.643146514892578
# max value in residual: 273378848.0
# Max value in variance: 35259964.0
# Max value in quasi_likelihood_log: 15.369463920593262
# ...
#     190 if result.loss is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py:265, in _AutomaticOptimization._optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     262     self.optim_progress.optimizer.step.increment_ready()
#     264 # model hook
# --> 265 call._call_lightning_module_hook(
#     266     trainer,
#     267     "optimizer_step",
#     268     trainer.current_epoch,
#     269     batch_idx,
#     270     optimizer,
#     271     train_step_and_backward_closure,
#     272 )
#     274 if not should_accumulate:
#     275     self.optim_progress.optimizer.step.increment_completed()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:157, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     154 pl_module._current_fx_name = hook_name
#     156 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 157     output = fn(*args, **kwargs)
#     159 # restore current_fx when nested context
#     160 pl_module._current_fx_name = prev_fx_name
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/core/module.py:1291, in LightningModule.optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1252 def optimizer_step(
#    1253     self,
#    1254     epoch: int,
#    (...)
#    1257     optimizer_closure: Optional[Callable[[], Any]] = None,
#    1258 ) -> None:
#    1259     r"""Override this method to adjust the default way the :class:`~lightning.pytorch.trainer.trainer.Trainer` calls
#    1260     the optimizer.
#    1261
#    (...)
#    1289
#    1290     """
# -> 1291     optimizer.step(closure=optimizer_closure)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/core/optimizer.py:151, in LightningOptimizer.step(self, closure, **kwargs)
#     148     raise MisconfigurationException("When `optimizer.step(closure)` is called, the closure should be callable")
#     150 assert self._strategy is not None
# --> 151 step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     153 self._on_after_step()
#     155 return step_output
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py:230, in Strategy.optimizer_step(self, optimizer, closure, model, **kwargs)
#     228 # TODO(fabric): remove assertion once strategy's optimizer_step typing is fixed
#     229 assert isinstance(model, pl.LightningModule)
# --> 230 return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/plugins/precision/precision.py:117, in Precision.optimizer_step(self, optimizer, model, closure, **kwargs)
#     115 """Hook to run the optimizer step."""
#     116 closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 117 return optimizer.step(closure=closure, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/optim/adam.py:148, in Adam.step(self, closure)
#     146 if closure is not None:
#     147     with torch.enable_grad():
# --> 148         loss = closure()
#     150 for group in self.param_groups:
#     151     params_with_grad = []
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/plugins/precision/precision.py:104, in Precision._wrap_closure(self, model, optimizer, closure)
#      91 def _wrap_closure(
#      92     self,
#      93     model: "pl.LightningModule",
#      94     optimizer: Optimizer,
#      95     closure: Callable[[], Any],
#      96 ) -> Any:
#      97     """This double-closure allows makes sure the ``closure`` is executed before the ``on_before_optimizer_step``
#      98     hook is called.
#      99
#    (...)
#     102
#     103     """
# --> 104     closure_result = closure()
#     105     self._after_closure(model, optimizer)
#     106     return closure_result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py:140, in Closure.__call__(self, *args, **kwargs)
#     139 def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 140     self._result = self.closure(*args, **kwargs)
#     141     return self._result.loss
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py:126, in Closure.closure(self, *args, **kwargs)
#     124 @torch.enable_grad()
#     125 def closure(self, *args: Any, **kwargs: Any) -> ClosureResult:
# --> 126     step_output = self._step_fn()
#     128     if step_output.closure_loss is None:
#     129         self.warning_cache.warn("`training_step` returned `None`. If this was on purpose, ignore this warning...")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/loops/optimization/automatic.py:315, in _AutomaticOptimization._training_step(self, kwargs)
#     312 trainer = self.trainer
#     314 # manually capture logged metrics
# --> 315 training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#     316 self.trainer.strategy.post_training_step()  # unused hook - call anyway for backward compatibility
#     318 return self.output_result_cls.from_training_step_output(training_step_output, trainer.accumulate_grad_batches)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/trainer/call.py:309, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     306     return None
#     308 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 309     output = fn(*args, **kwargs)
#     311 # restore current_fx when nested context
#     312 pl_module._current_fx_name = prev_fx_name
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/lightning/pytorch/strategies/strategy.py:382, in Strategy.training_step(self, *args, **kwargs)
#     380 if self.model != self.lightning_module:
#     381     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
# --> 382 return self.lightning_module.training_step(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/train/_trainingplans.py:343, in TrainingPlan.training_step(self, batch, batch_idx)
#     341     self.loss_kwargs.update({"kl_weight": kl_weight})
#     342     self.log("kl_weight", kl_weight, on_step=True, on_epoch=False)
# --> 343 _, _, scvi_loss = self.forward(batch, loss_kwargs=self.loss_kwargs)
#     344 self.log(
#     345     "train_loss",
#     346     scvi_loss.loss,
#    (...)
#     349     sync_dist=self.use_sync_dist,
#     350 )
#     351 self.compute_and_log_metrics(scvi_loss, self.train_metrics, "train")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/train/_trainingplans.py:277, in TrainingPlan.forward(self, *args, **kwargs)
#     275 def forward(self, *args, **kwargs):
#     276     """Passthrough to the module's forward method."""
# --> 277     return self.module(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/module/base/_decorators.py:32, in auto_move_data.<locals>.auto_transfer_args(self, *args, **kwargs)
#      30 # decorator only necessary after training
#      31 if self.training:
# ---> 32     return fn(self, *args, **kwargs)
#      34 device = list({p.device for p in self.parameters()})
#      35 if len(device) > 1:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/module/base/_base_module.py:203, in BaseModuleClass.forward(self, tensors, get_inference_input_kwargs, get_generative_input_kwargs, inference_kwargs, generative_kwargs, loss_kwargs, compute_loss)
#     172 @auto_move_data
#     173 def forward(
#     174     self,
#    (...)
#     181     compute_loss=True,
#     182 ) -> tuple[torch.Tensor, torch.Tensor] | tuple[torch.Tensor, torch.Tensor, LossOutput]:
#     183     """Forward pass through the network.
#     184
#     185     Parameters
#    (...)
#     201         another return value.
#     202     """
# --> 203     return _generic_forward(
#     204         self,
#     205         tensors,
#     206         inference_kwargs,
#     207         generative_kwargs,
#     208         loss_kwargs,
#     209         get_inference_input_kwargs,
#     210         get_generative_input_kwargs,
#     211         compute_loss,
#     212     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/module/base/_base_module.py:743, in _generic_forward(module, tensors, inference_kwargs, generative_kwargs, loss_kwargs, get_inference_input_kwargs, get_generative_input_kwargs, compute_loss)
#     740 get_generative_input_kwargs = _get_dict_if_none(get_generative_input_kwargs)
#     742 inference_inputs = module._get_inference_input(tensors, **get_inference_input_kwargs)
# --> 743 inference_outputs = module.inference(**inference_inputs, **inference_kwargs)
#     744 generative_inputs = module._get_generative_input(
#     745     tensors, inference_outputs, **get_generative_input_kwargs
#     746 )
#     747 generative_outputs = module.generative(**generative_inputs, **generative_kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/module/base/_decorators.py:32, in auto_move_data.<locals>.auto_transfer_args(self, *args, **kwargs)
#      30 # decorator only necessary after training
#      31 if self.training:
# ---> 32     return fn(self, *args, **kwargs)
#      34 device = list({p.device for p in self.parameters()})
#      35 if len(device) > 1:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/module/base/_base_module.py:307, in BaseMinifiedModeModuleClass.inference(self, *args, **kwargs)
#     305     return self._cached_inference(*args, **kwargs)
#     306 else:
# --> 307     return self._regular_inference(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/module/base/_decorators.py:32, in auto_move_data.<locals>.auto_transfer_args(self, *args, **kwargs)
#      30 # decorator only necessary after training
#      31 if self.training:
# ---> 32     return fn(self, *args, **kwargs)
#      34 device = list({p.device for p in self.parameters()})
#      35 if len(device) > 1:
#
# File ~/thesis/thesis/thesis/_quasivae.py:290, in QuasiVAE._regular_inference(self, x, batch_index, cont_covs, cat_covs, n_samples)
#     288     qz, z = self.z_encoder(encoder_input, *categorical_input)
#     289 else:
# --> 290     qz, z = self.z_encoder(encoder_input, batch_index, *categorical_input)
#     292 ql = None
#     293 if not self.use_observed_lib_size:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/nn/_base_components.py:282, in Encoder.forward(self, x, *cat_list)
#     280 q_m = self.mean_encoder(q)
#     281 q_v = self.var_activation(self.var_encoder(q)) + self.var_eps
# --> 282 dist = Normal(q_m, q_v.sqrt())
#     283 latent = self.z_transformation(dist.rsample())
#     284 if self.return_dist:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/distributions/normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/distributions/distribution.py:68, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      66         valid = constraint.check(value)
#      67         if not valid.all():
# ---> 68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      71                 f"of distribution {repr(self)} "
#      72                 f"to satisfy the constraint {repr(constraint)}, "
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (128, 10)) of distribution Normal(loc: torch.Size([128, 10]), scale: torch.Size([128, 10])) to satisfy the constraint Real(), but found invalid values:
# tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], grad_fn=<AddmmBackward0>)

# %%
# Plot training loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss_history, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()

# Plot KL divergence
plt.subplot(1, 2, 2)
plt.plot(kl_divergence_history, label='KL Divergence', color='orange')
plt.xlabel('Epochs')
plt.ylabel('KL Divergence')
plt.title('KL Divergence over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Now we obtain the latent representation, and use Scanpy to visualize with UMAP.

# %%
SCVI_LATENT_KEY = "X_scVI"

pancreas_ref.obsm[SCVI_LATENT_KEY] = custom_scvi.get_latent_representation()
sc.pp.neighbors(pancreas_ref, use_rep=SCVI_LATENT_KEY)
sc.tl.leiden(pancreas_ref)
sc.tl.umap(pancreas_ref)

# %%
sc.pl.umap(
    pancreas_ref,
    color=["tech", "celltype"],
    frameon=False,
    ncols=1,
)

# %%
custom_scvi.history.keys()
