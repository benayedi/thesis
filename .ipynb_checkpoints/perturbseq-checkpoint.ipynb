# %%
import os
import tempfile

import anndata as ad
import muon
import numpy as np
import scanpy as sc
import seaborn as sns
import torch
import muon as mu
import pertpy as pt
import pandas as pd
import re
import torch

from _quasiSCVI import QuasiSCVI
from _quasivae import QuasiVAE
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
import scvi
print(scvi.__version__)
# Out:
# 1.1.3

# %%
sc.set_figure_params(figsize=(6, 6), frameon=False)
sns.set_theme()
torch.set_float32_matmul_precision("high")
save_dir = tempfile.TemporaryDirectory()

# %config InlineBackend.print_figure_kwargs={"facecolor": "w"}
# %config InlineBackend.figure_format="retina"

# %%
# Load the .h5ad file
adata = ad.read_h5ad('/Users/ismail/thesis/Baf single gene guide qc lm.h5ad')

# Display the object
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 38328 × 1289
#     obs: 'n_genes', 'batch', 'cell', 'control', 'guide.compact', 'gene.compact', 'unassigned', 'n_genes_by_counts', 'total_counts_mt', 'leiden', 'cell_state', 'SS18_4', 'BCL7A_4', 'SMARCE1_4', 'SS18L_1', 'BCL7B_2', 'SMARCA4_5', 'ARID2_3', 'SMARCD3_3', 'SMARCA2_1', 'BRD9_4', 'GLTSCR1_4', 'SMARCC2_3', 'SS18L_3', 'PHF10_3', 'NTC2_IG216151', 'DPF2_3', 'SS18L_2', 'ARID2_2', 'BCL7C_2', 'PBRM1_3', 'BCL7A_2', 'ARID2_1', 'BCL7B_3', 'GLTSCR1L_4', 'SMARCC2_2', 'SMARCA2_2', 'BRD7_4', 'DPF3_3', 'SMARCB1_5', 'BRD9_2', 'ARID2_4', 'GLTSCR1L_2', 'PHF10_4', 'SMARCA4_1', 'SMARCA4_4', 'ACTL6A_2', 'SS18L_4', 'BCL7B_4', 'SMARCD2_4', 'SMARCD1_2', 'NTC7_IG1144056', 'DPF3_2', 'SMARCA4_7', 'BRD7_3', 'BCL7B_1', 'DPF1_2', 'SMARCD2_2', 'ARID1A_2', 'PHF10_2', 'SMARCC1_7', 'NTC5_mNTC100A67005', 'BCL7A_3', 'SMARCD2_1', 'SMARCD2_3', 'SMARCE1_2', 'BCL7C_3', 'SMARCB1_7', 'BRD7_2', 'SS18_3', 'ACTL6B_1', 'BRD9_1', 'ACTL6A_1', 'SMARCC1_1', 'PBRM1_2', 'ARID1B_4', 'GLTSCR1_1', 'DPF3_4', 'SMARCC2_4', 'DPF1_3', 'SMARCD3_1', 'ARID1B_1', 'ACTL6A_3', 'DPF2_4', 'NTC1_IG345439', 'ACTL6B_3', 'SMARCD3_2', 'SMARCC1_2', 'DPF1_4', 'SMARCB1_1', 'ARID1B_3', 'ARID1A_5', 'GLTSCR1_3', 'DPF2_2', 'DPF3_1', 'SMARCE1_1', 'ACTL6B_4', 'SMARCE1_3', 'SMARCB1_8', 'PBRM1_1', 'BCL7A_1', 'ACTL6B_2', 'BCL7C_4', 'DPF2_1', 'SMARCD3_4', 'SMARCC2_1', 'ARID1A_7', 'PBRM1_4', 'SMARCD1_1', 'SS18_1', 'BRD9_3', 'PHF10_1', 'ARID1A_3', 'ARID1B_2', 'SS18_2', 'GLTSCR1L_1', 'SMARCA2_3', 'ACTL6A_4', 'BCL7C_1', 'GLTSCR1L_3', 'SMARCD1_3', 'DPF1_1', 'SMARCC1_5', 'SMARCA2_4', 'SMARCD1_4', 'NTC6_IG1216445', 'BRD7_1', 'ARID1B', 'DPF3', 'BCL7C', 'ACTL6B', 'SS18', 'GLTSCR1L', 'SMARCC1', 'SMARCD1', 'DPF1', 'ACTL6A', 'BRD9', 'DPF2', 'SMARCC2', 'SMARCB1', 'GLTSCR1', 'ARID1A', 'BCL7B', 'BCL7A', 'SMARCD3', 'ARID2', 'SMARCD2', 'SS18L', 'PBRM1', 'SMARCA2', 'BRD7', 'SMARCA4', 'PHF10', 'SMARCE1', 'guide', 'gene', 'perturbs_per_cell.guide', 'guide_qc', 'profile', 'guide.compact.with_control', 'batch_num0', 'batch_num1', 'batch_num2', 'batch_num3', 'batch_num4', 'batch_num5', 'batch_num6', 'batch_num7', 'batch_num8', 'batch_num9', 'batch_num10', 'batch_num11', 'batch_num12', 'batch_num13', 'batch_num14', 'n_counts', 'percent_mito', 'PS.train_valid_test', 'P0', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', '.P0', '.P1', '.P2', '.P3', '.P4', '.P5', '.P6', '.P7', '.P8', '.P9', '.P10', '.P11'
#     var: 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std', 'coef.gene2.program', 'coef.gene2.program_color', 'new_program', 'new_program.color'
#     uns: 'PS.alpha.0.0005.X', 'PS.alpha.0.0005.coef', 'PS.alpha.0.0005.covariates', 'PS.alpha.0.0005.y', 'PS.alpha.0.005.X', 'PS.alpha.0.005.coef', 'PS.alpha.0.005.covariates', 'PS.alpha.0.005.y', 'PS.alpha.0.05.X', 'PS.alpha.0.05.coef', 'PS.alpha.0.05.covariates', 'PS.alpha.0.05.y', 'PS.alpha.5e-05.X', 'PS.alpha.5e-05.coef', 'PS.alpha.5e-05.covariates', 'PS.alpha.5e-05.y', 'SMARCA4_4', 'cell_state_colors', 'cells_per_perturb.gene', 'cells_per_perturb.gene.incl_multi_inf', 'cells_per_perturb.gene.singly_inf', 'cells_per_perturb.guide', 'cells_per_perturb.guide.incl_multi_inf', 'cells_per_perturb.guide.singly_inf', 'coef.gene2', 'coef.gene2.perturbation_module', 'coef.gene2.perturbation_module_color', 'guide2gene', 'guide_qc_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'sorted_genes', 'sorted_guides', 'target_gene_expr_in_control', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       n_genes batch cell control guide.compact gene.compact  \
# TTGCATTTCGGTAGAG-1-8     4364     8  0.0     0.0     SMARCA2_3      SMARCA2
# TTTGGTTGTAGGTTTC-1-6     4523     6  0.0     0.0    unassigned   unassigned
# CACGTGGCAGGCATGA-1-8     3016     8  0.0     0.0       BCL7B_1        BCL7B
# ACCAAACGTTGAAGTA-1-12    5928    12  0.0     0.0    unassigned   unassigned
# CTCAGAAAGACTCTAC-1-11    4594    11  0.0     0.0      ACTL6B_4       ACTL6B
# ...                       ...   ...  ...     ...           ...          ...
# AGAAGCGTCAGGACGA-1-9     4964     9  0.0     0.0       PBRM1_4        PBRM1
# GTTGCGGCAACCCGCA-1-6     6043     6  0.0     0.0       BCL7A_1        BCL7A
# GGAGATGAGTAGAATC-1-0     3582     0  0.0     0.0    unassigned   unassigned
# TCTTTGAGTCAGTTTG-1-6     4472     6  0.0     0.0        SS18_3         SS18
# GCTACAAGTATACCCA-1-2     4423     2  0.0     0.0     GLTSCR1_1      GLTSCR1
#
#                        unassigned n_genes_by_counts total_counts_mt leiden  \
# TTGCATTTCGGTAGAG-1-8            0              4364          1777.0      2
# TTTGGTTGTAGGTTTC-1-6            1              4523          1697.0      4
# CACGTGGCAGGCATGA-1-8            0              3016           896.0      5
# ACCAAACGTTGAAGTA-1-12           1              5928          2412.0      3
# CTCAGAAAGACTCTAC-1-11           0              4594          1859.0      1
# ...                           ...               ...             ...    ...
# AGAAGCGTCAGGACGA-1-9            0              4963          2287.0      3
# GTTGCGGCAACCCGCA-1-6            0              6043          3493.0      3
# GGAGATGAGTAGAATC-1-0            1              3582          1196.0      0
# TCTTTGAGTCAGTTTG-1-6            0              4472          1646.0      4
# GCTACAAGTATACCCA-1-2            0              4423          1523.0      3
#
#                        ...       .P2       .P3       .P4       .P5       .P6  \
# TTGCATTTCGGTAGAG-1-8   ...  0.209884  0.091023 -0.079784 -0.052859 -0.023871
# TTTGGTTGTAGGTTTC-1-6   ...  0.303646  0.034636 -0.066206 -0.037091 -0.135707
# CACGTGGCAGGCATGA-1-8   ... -0.274533  0.024449  0.149817 -0.087757 -0.088601
# ACCAAACGTTGAAGTA-1-12  ... -0.158908  0.048270 -0.066180 -0.016550 -0.008066
# CTCAGAAAGACTCTAC-1-11  ...  0.190171 -0.011801 -0.069991 -0.067258 -0.045424
# ...                    ...       ...       ...       ...       ...       ...
# AGAAGCGTCAGGACGA-1-9   ... -0.124360  0.092573 -0.120545 -0.052604 -0.071641
# GTTGCGGCAACCCGCA-1-6   ...  0.045556  0.042191 -0.087506 -0.045139 -0.055465
# GGAGATGAGTAGAATC-1-0   ...  0.312022  0.013156  0.010845 -0.054402 -0.055282
# TCTTTGAGTCAGTTTG-1-6   ...  0.304349  0.027444 -0.038663 -0.064119 -0.075211
# GCTACAAGTATACCCA-1-2   ...  0.082831  0.182426 -0.087829 -0.060270 -0.061727
#
#                             .P7       .P8       .P9      .P10      .P11
# TTGCATTTCGGTAGAG-1-8  -0.106268 -0.065490 -0.093925 -0.138877 -0.126892
# TTTGGTTGTAGGTTTC-1-6  -0.066927 -0.108650 -0.121789 -0.145670 -0.134484
# CACGTGGCAGGCATGA-1-8  -0.031453 -0.077011 -0.125244 -0.046160 -0.135437
# ACCAAACGTTGAAGTA-1-12 -0.044271 -0.119790 -0.104319 -0.118289 -0.167694
# CTCAGAAAGACTCTAC-1-11 -0.100850 -0.142342 -0.088255 -0.152857 -0.147155
# ...                         ...       ...       ...       ...       ...
# AGAAGCGTCAGGACGA-1-9  -0.061278 -0.111678 -0.107756 -0.133673 -0.133523
# GTTGCGGCAACCCGCA-1-6   0.004878 -0.104217 -0.095756 -0.132171 -0.180121
# GGAGATGAGTAGAATC-1-0  -0.136859 -0.161164 -0.071691 -0.107270 -0.123363
# TCTTTGAGTCAGTTTG-1-6  -0.041830 -0.099594 -0.116923 -0.120978 -0.112966
# GCTACAAGTATACCCA-1-2  -0.031232 -0.145354 -0.115711 -0.113000 -0.156943
#
# [38328 rows x 203 columns]

# %%
adata.var
# Out:
#        n_cells     mt  n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# MUC1     15025  False              15025     0.347607              73.686054
# CCR1      7732  False               7732     0.177831              86.458607
# RBKS      4499  False               4499     0.088460              92.120703
# F3       25422  False              25422     0.945831              55.477329
# TXNIP    33982  False              33982     1.456751              40.485823
# ...        ...    ...                ...          ...                    ...
# MCUB      9540  False               9540     0.204767              83.292177
# ABCA1     1220  False               1220     0.023976              97.863360
# FEZ1      3985  False               3985     0.121911              93.020894
# NBR1     11367  False              11367     0.245153              80.092471
# FMNL1    20819  False              20819     0.524668              63.538766
#
#        total_counts  highly_variable     means  dispersions  dispersions_norm  \
# MUC1        19848.0             True  0.165828    -0.308917          0.504095
# CCR1        10154.0             True  0.093780     0.003922          1.731725
# RBKS         5051.0             True  0.047697    -0.285813          0.594757
# F3          54006.0             True  0.396673     0.229081          2.783264
# TXNIP       83179.0             True  0.583369     0.616224          3.883252
# ...             ...              ...       ...          ...               ...
# MCUB        11692.0             True  0.105099    -0.290108          0.577905
# ABCA1        1369.0             True  0.013932     0.017293          1.784193
# FEZ1         6961.0             True  0.074822     0.443046          3.454918
# NBR1        13998.0             True  0.120634    -0.271094          0.652518
# FMNL1       29958.0             True  0.248421    -0.247424          0.745404
#
#                mean       std  coef.gene2.program coef.gene2.program_color  \
# MUC1   1.732787e-11  0.237323                   9                  #fc8d62
# CCR1   1.279599e-11  0.193050                   7                  #b3b3b3
# RBKS  -2.428771e-11  0.132941                   7                  #b3b3b3
# F3    -2.281654e-13  0.389663                   1                  #fc8d62
# TXNIP  3.586021e-11  0.458277                   9                  #fc8d62
# ...             ...       ...                 ...                      ...
# MCUB  -3.278312e-12  0.194509                   9                  #fc8d62
# ABCA1  6.355938e-12  0.075058                   6                  #e5c494
# FEZ1  -1.630696e-11  0.191987                   6                  #e5c494
# NBR1  -1.103511e-12  0.204499                   9                  #fc8d62
# FMNL1  5.331608e-11  0.287942                  10                  #8da0cb
#
#       new_program new_program.color
# MUC1           P7           #66c2a5
# CCR1          P11           #fc8d62
# RBKS          P11           #fc8d62
# F3             P3           #8da0cb
# TXNIP          P7           #66c2a5
# ...           ...               ...
# MCUB           P7           #66c2a5
# ABCA1          P9           #e78ac3
# FEZ1           P9           #e78ac3
# NBR1           P7           #66c2a5
# FMNL1          P4           #b3b3b3
#
# [1289 rows x 16 columns]

# %%
def extract_guide_number(guide):
    if guide == 'unassigned':
        return '0'
    else:
        # Extract the numeric part after the underscore
        match = re.search(r'_(\d+)', guide)
        if match:
            return match.group(1)
        else:
            return np.nan

adata.obs['replicate'] = adata.obs['guide.compact'].apply(extract_guide_number)
adata.obs['replicate'] = adata.obs['replicate'].astype('category')

adata.obs["replicate"]
# Out:
# TTGCATTTCGGTAGAG-1-8     3
# TTTGGTTGTAGGTTTC-1-6     0
# CACGTGGCAGGCATGA-1-8     1
# ACCAAACGTTGAAGTA-1-12    0
# CTCAGAAAGACTCTAC-1-11    4
#                         ..
# AGAAGCGTCAGGACGA-1-9     4
# GTTGCGGCAACCCGCA-1-6     1
# GGAGATGAGTAGAATC-1-0     0
# TCTTTGAGTCAGTTTG-1-6     3
# GCTACAAGTATACCCA-1-2     1
# Name: replicate, Length: 38328, dtype: category
# Categories (8, object): ['0', '1', '2', '3', '4', '5', '7', '8']

# %%
adata.obs["gene.compact"]
# Out:
# TTGCATTTCGGTAGAG-1-8        SMARCA2
# TTTGGTTGTAGGTTTC-1-6     unassigned
# CACGTGGCAGGCATGA-1-8          BCL7B
# ACCAAACGTTGAAGTA-1-12    unassigned
# CTCAGAAAGACTCTAC-1-11        ACTL6B
#                             ...
# AGAAGCGTCAGGACGA-1-9          PBRM1
# GTTGCGGCAACCCGCA-1-6          BCL7A
# GGAGATGAGTAGAATC-1-0     unassigned
# TCTTTGAGTCAGTTTG-1-6           SS18
# GCTACAAGTATACCCA-1-2        GLTSCR1
# Name: gene.compact, Length: 38328, dtype: category
# Categories (30, object): ['ACTL6A', 'ACTL6B', 'ARID1A', 'ARID1B', ..., 'SS18', 'SS18L', 'control', 'unassigned']

# %%
perturbed_adata = adata[
    adata.obs["gene.compact"] != "unassigned"
]  # Only consider perturbed cells
perturbed_adata.obs
# Out:
#                       n_genes batch cell control guide.compact gene.compact  \
# TTGCATTTCGGTAGAG-1-8     4364     8  0.0     0.0     SMARCA2_3      SMARCA2
# CACGTGGCAGGCATGA-1-8     3016     8  0.0     0.0       BCL7B_1        BCL7B
# CTCAGAAAGACTCTAC-1-11    4594    11  0.0     0.0      ACTL6B_4       ACTL6B
# CATCAAGCAAGCGGAT-1-4     4865     4  0.0     0.0        DPF3_2         DPF3
# ATTCTTGAGTTTCAGC-1-2     4097     2  0.0     0.0       BCL7B_3        BCL7B
# ...                       ...   ...  ...     ...           ...          ...
# TCGGATACAATAAGGT-1-8     4504     8  0.0     0.0       BCL7B_3        BCL7B
# AGAAGCGTCAGGACGA-1-9     4964     9  0.0     0.0       PBRM1_4        PBRM1
# GTTGCGGCAACCCGCA-1-6     6043     6  0.0     0.0       BCL7A_1        BCL7A
# TCTTTGAGTCAGTTTG-1-6     4472     6  0.0     0.0        SS18_3         SS18
# GCTACAAGTATACCCA-1-2     4423     2  0.0     0.0     GLTSCR1_1      GLTSCR1
#
#                        unassigned n_genes_by_counts total_counts_mt leiden  \
# TTGCATTTCGGTAGAG-1-8            0              4364          1777.0      2
# CACGTGGCAGGCATGA-1-8            0              3016           896.0      5
# CTCAGAAAGACTCTAC-1-11           0              4594          1859.0      1
# CATCAAGCAAGCGGAT-1-4            0              4865          2032.0      6
# ATTCTTGAGTTTCAGC-1-2            0              4097          1335.0      3
# ...                           ...               ...             ...    ...
# TCGGATACAATAAGGT-1-8            0              4504          1786.0      0
# AGAAGCGTCAGGACGA-1-9            0              4963          2287.0      3
# GTTGCGGCAACCCGCA-1-6            0              6043          3493.0      3
# TCTTTGAGTCAGTTTG-1-6            0              4472          1646.0      4
# GCTACAAGTATACCCA-1-2            0              4423          1523.0      3
#
#                        ...       .P3       .P4       .P5       .P6       .P7  \
# TTGCATTTCGGTAGAG-1-8   ...  0.091023 -0.079784 -0.052859 -0.023871 -0.106268
# CACGTGGCAGGCATGA-1-8   ...  0.024449  0.149817 -0.087757 -0.088601 -0.031453
# CTCAGAAAGACTCTAC-1-11  ... -0.011801 -0.069991 -0.067258 -0.045424 -0.100850
# CATCAAGCAAGCGGAT-1-4   ...  0.083702 -0.101828  0.053535 -0.028463 -0.046678
# ATTCTTGAGTTTCAGC-1-2   ...  0.047590 -0.041850  0.062592 -0.139507  0.079137
# ...                    ...       ...       ...       ...       ...       ...
# TCGGATACAATAAGGT-1-8   ...  0.108813 -0.109756 -0.078059 -0.038733 -0.153273
# AGAAGCGTCAGGACGA-1-9   ...  0.092573 -0.120545 -0.052604 -0.071641 -0.061278
# GTTGCGGCAACCCGCA-1-6   ...  0.042191 -0.087506 -0.045139 -0.055465  0.004878
# TCTTTGAGTCAGTTTG-1-6   ...  0.027444 -0.038663 -0.064119 -0.075211 -0.041830
# GCTACAAGTATACCCA-1-2   ...  0.182426 -0.087829 -0.060270 -0.061727 -0.031232
#
#                             .P8       .P9      .P10      .P11 replicate
# TTGCATTTCGGTAGAG-1-8  -0.065490 -0.093925 -0.138877 -0.126892         3
# CACGTGGCAGGCATGA-1-8  -0.077011 -0.125244 -0.046160 -0.135437         1
# CTCAGAAAGACTCTAC-1-11 -0.142342 -0.088255 -0.152857 -0.147155         4
# CATCAAGCAAGCGGAT-1-4  -0.105566 -0.110459 -0.131653 -0.159632         2
# ATTCTTGAGTTTCAGC-1-2  -0.095947 -0.136911 -0.075055 -0.138381         3
# ...                         ...       ...       ...       ...       ...
# TCGGATACAATAAGGT-1-8  -0.102016 -0.092018 -0.135454 -0.137559         3
# AGAAGCGTCAGGACGA-1-9  -0.111678 -0.107756 -0.133673 -0.133523         4
# GTTGCGGCAACCCGCA-1-6  -0.104217 -0.095756 -0.132171 -0.180121         1
# TCTTTGAGTCAGTTTG-1-6  -0.099594 -0.116923 -0.120978 -0.112966         3
# GCTACAAGTATACCCA-1-2  -0.145354 -0.115711 -0.113000 -0.156943         1
#
# [22425 rows x 204 columns]

# %%
# layer_names = adata.layers.keys()
# print("Layers in AnnData object:", list(layer_names))
# # Inspect each layer's data matrix
# for layer_name in layer_names:
#     print(f"Layer '{layer_name}' data matrix:")
#     print(adata.layers[layer_name])

# %%
adata_ref = adata.copy()

# %%
QuasiSCVI.setup_anndata(adata_ref, batch_key="replicate", layer="counts")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 QuasiSCVI.setup_anndata(adata_ref, batch_key="replicate", layer="counts")
#
# File ~/thesis/thesis/thesis/_quasiSCVI.py:164, in QuasiSCVI.setup_anndata(cls, adata, layer, batch_key, labels_key, size_factor_key, categorical_covariate_keys, continuous_covariate_keys, **kwargs)
#     162     anndata_fields += cls._get_fields_for_adata_minification(adata_minify_type)
#     163 adata_manager = AnnDataManager(fields=anndata_fields, setup_method_args=setup_method_args)
# --> 164 adata_manager.register_fields(adata, **kwargs)
#     165 cls.register_manager(adata_manager)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/data/_manager.py:180, in AnnDataManager.register_fields(self, adata, source_registry, **transfer_kwargs)
#     177 self._validate_anndata_object(adata)
#     179 for field in self.fields:
# --> 180     self._add_field(
#     181         field=field,
#     182         adata=adata,
#     183         source_registry=source_registry,
#     184         **transfer_kwargs,
#     185     )
#     187 # Save arguments for register_fields.
#     188 self._source_registry = deepcopy(source_registry)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/data/_manager.py:223, in AnnDataManager._add_field(self, field, adata, source_registry, **transfer_kwargs)
#     215         field_registry[_constants._STATE_REGISTRY_KEY] = field.transfer_field(
#     216             source_registry[_constants._FIELD_REGISTRIES_KEY][field.registry_key][
#     217                 _constants._STATE_REGISTRY_KEY
#    (...)
#     220             **transfer_kwargs,
#     221         )
#     222     else:
# --> 223         field_registry[_constants._STATE_REGISTRY_KEY] = field.register_field(adata)
#     224 # Compute and set summary stats for the given field.
#     225 state_registry = field_registry[_constants._STATE_REGISTRY_KEY]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/data/fields/_dataframe_field.py:186, in CategoricalDataFrameField.register_field(self, adata)
#     183     self._setup_default_attr(adata)
#     185 super().register_field(adata)
# --> 186 categorical_mapping = _make_column_categorical(
#     187     getattr(adata, self.attr_name),
#     188     self._original_attr_key,
#     189     self.attr_key,
#     190 )
#     191 return {
#     192     self.CATEGORICAL_MAPPING_KEY: categorical_mapping,
#     193     self.ORIGINAL_ATTR_KEY: self._original_attr_key,
#     194 }
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scvi/data/_utils.py:223, in _make_column_categorical(df, column_key, alternate_column_key, categorical_dtype)
#     221 if -1 in unique:
#     222     received_categories = df[column_key].astype("category").cat.categories
# --> 223     raise ValueError(
#     224         f'Making .obs["{column_key}"] categorical failed. Expected categories: {mapping}. '
#     225         f"Received categories: {received_categories}. "
#     226     )
#     227 df[alternate_column_key] = codes
#     229 # make sure each category contains enough cells
#
# ValueError: Making .obs["replicate"] categorical failed. Expected categories: ['0' '1' '2' '3' '4' '5' '7' '8']. Received categories: Index(['0', '1', '2', '3', '4', '5', '7', '8'], dtype='object').

# %%
# Initialize the Quasi SCVI model
scvi_ref = QuasiSCVI(
    adata_ref,
    use_layer_norm="both",
    use_batch_norm="none",
    encode_covariates=True,
    dropout_rate=0.2,
    n_layers=2,
)

# Train the model
scvi_ref.train(max_epochs=200, plan_kwargs={"lr": 1e-4})

# %%
scvi_ref.history["elbo_train"]
train_loss = scvi_ref.history["elbo_train"]
kl_divergence = scvi_ref.history["kl_local_train"]

# %%
# Plot training loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.legend()

# Plot KL divergence
plt.subplot(1, 2, 2)
plt.plot(kl_divergence, label='KL Divergence', color='orange')
plt.xlabel('Epochs')
plt.ylabel('KL Divergence')
plt.title('KL Divergence over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
SCVI_LATENT_KEY = "X_scVI"

pancreas_ref.obsm[SCVI_LATENT_KEY] = scvi_ref.get_latent_representation()
sc.pp.neighbors(pancreas_ref, use_rep=SCVI_LATENT_KEY)
sc.tl.leiden(pancreas_ref)
sc.tl.umap(pancreas_ref)

# %%
sc.pl.umap(
    pancreas_ref,
    color=["tech", "celltype"],
    frameon=False,
    ncols=1,
)
